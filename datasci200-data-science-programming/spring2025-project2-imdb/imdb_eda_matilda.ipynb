# %% [markdown]
# # Project 2
# Dataset Source: [IMDb Top 1000 Movies Kaggle Dataset](https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows/data)

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
pd.set_option('display.float_format', lambda x: '%.2f' %x)
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
palette = sns.color_palette('Set2')

import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')
from matplotlib.ticker import FuncFormatter

def currency_formatter(x, pos):
    return '$%.2f' % x

def millions(x, pos):
    return f'${x*1e-6:.0f}M'

print("All modules loaded")
# Out:
# All modules loaded

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv('./data/imdb_top_1000.csv')

# %%
print("Dataset Size:", df.shape)
df.head()
# Out:
# Dataset Size: (1000, 16)
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama         9.30
# 1          Crime, Drama         9.20
# 2  Action, Crime, Drama         9.00
# 3          Crime, Drama         9.00
# 4          Crime, Drama         9.00
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...       80.00
# 1  An organized crime dynasty's aging patriarch t...      100.00
# 2  When the menace known as the Joker wreaks havo...       84.00
# 3  The early life and career of Vito Corleone in ...       90.00
# 4  A jury holdout attempts to prevent a miscarria...       96.00
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# ### Missing value and Duplicate check

# %%
df.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score  No_of_Votes
# count      1000.00      843.00      1000.00
# mean          7.95       77.97    273692.91
# std           0.28       12.38    327372.70
# min           7.60       28.00     25088.00
# 25%           7.70       70.00     55526.25
# 50%           7.90       79.00    138548.50
# 75%           8.10       87.00    374161.25
# max           9.30      100.00   2343110.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# To do:
# ### 1. Rename columns for easier and consistent naming
#
# ### 2. Impute missing values for:
# * cert (done) -> decided to do "Not Rated"
# * meta_score (done) -> filled with mean for now
#
# ### 3. Transform to Numerical values:
# 1. year (done)
# 2. runtime (done)
#
# ### 4. Impute and transform `gross`

# %%
# 1. rename columns to lowercase 
df.columns = df.columns.str.lower()

# %%
# rename to easier names 
df = df.rename(columns={
    'poster_link': 'link',
    'series_title': 'title', 
    'certificate': 'cert', 
    'released_year': 'year',
})

print(df.columns)
# Out:
# Index(['link', 'title', 'year', 'cert', 'runtime', 'genre', 'imdb_rating',
#        'overview', 'meta_score', 'director', 'star1', 'star2', 'star3',
#        'star4', 'no_of_votes', 'gross'],
#       dtype='object')

# %%
# 2. imputing missing values
df['cert'] = df['cert'].fillna('Unrated')
df['meta_score'] = df['meta_score'].fillna(df['meta_score'].mean())

# %%
# 3.1 transforming year to appropriate data type
df['year'].value_counts()
# interesting "PG" is a year
# Out:
# year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %%
df["year"] = pd.to_datetime(df["year"], format="%Y", errors="coerce") # transforms any invalid characters to NaT
df["decade"] = (df["year"].dt.year // 10) * 10

# %%
# Check the DataFrame again
print("\nAfter parsing:\n", df)

# View rows that failed to parse
invalid_rows = df[df["year"].isnull()]
print("\nRows with invalid years:\n", invalid_rows)
# Out:
# After parsing:
#                                                    link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                         title       year     cert  runtime  \
# 0    The Shawshank Redemption 1994-01-01        A  142 min
# 1               The Godfather 1972-01-01        A  175 min
# 2             The Dark Knight 2008-01-01       UA  152 min
# 3      The Godfather: Part II 1974-01-01        A  202 min
# 4                12 Angry Men 1957-01-01        U   96 min
# ..                        ...        ...      ...      ...
# 995    Breakfast at Tiffany's 1961-01-01        A  115 min
# 996                     Giant 1956-01-01        G  201 min
# 997     From Here to Eternity 1953-01-01   Passed  118 min
# 998                  Lifeboat 1944-01-01  Unrated   97 min
# 999              The 39 Steps 1935-01-01  Unrated   86 min
#
#                         genre  imdb_rating  \
# 0                       Drama         9.30
# 1                Crime, Drama         9.20
# 2        Action, Crime, Drama         9.00
# 3                Crime, Drama         9.00
# 4                Crime, Drama         9.00
# ..                        ...          ...
# 995    Comedy, Drama, Romance         7.60
# 996            Drama, Western         7.60
# 997       Drama, Romance, War         7.60
# 998                Drama, War         7.60
# 999  Crime, Mystery, Thriller         7.60
#
#                                               overview  meta_score  \
# 0    Two imprisoned men bond over a number of years...       80.00
# 1    An organized crime dynasty's aging patriarch t...      100.00
# 2    When the menace known as the Joker wreaks havo...       84.00
# 3    The early life and career of Vito Corleone in ...       90.00
# 4    A jury holdout attempts to prevent a miscarria...       96.00
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...       76.00
# 996  Sprawling epic covering the life of a Texas ca...       84.00
# 997  In Hawaii in 1941, a private is cruelly punish...       85.00
# 998  Several survivors of a torpedoed merchant ship...       78.00
# 999  A man in London tries to help a counter-espion...       93.00
#
#                  director              star1              star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               star3           star4  no_of_votes        gross  decade
# 0        Bob Gunton  William Sadler      2343110   28,341,469 1990.00
# 1        James Caan    Diane Keaton      1620367  134,966,411 1970.00
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444 2000.00
# 3     Robert Duvall    Diane Keaton      1129952   57,300,000 1970.00
# 4     Martin Balsam    John Fiedler       689845    4,360,000 1950.00
# ..              ...             ...          ...          ...     ...
# 995   Patricia Neal     Buddy Ebsen       166544          NaN 1960.00
# 996      James Dean   Carroll Baker        34075          NaN 1950.00
# 997    Deborah Kerr      Donna Reed        43374   30,500,000 1950.00
# 998   Walter Slezak  William Bendix        26471          NaN 1940.00
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN 1930.00
#
# [1000 rows x 17 columns]
#
# Rows with invalid years:
#                                                    link      title year cert  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...  Apollo 13  NaT    U
#
#      runtime                      genre  imdb_rating  \
# 966  140 min  Adventure, Drama, History         7.60
#
#                                               overview  meta_score  \
# 966  NASA must devise a strategy to return Apollo 1...       77.00
#
#        director      star1        star2        star3        star4  \
# 966  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      no_of_votes        gross  decade
# 966       269197  173,837,933     NaN

# %%
df = df.dropna(subset=["year"]) # drop row with invalid year value `PG`
print(df.shape)
# Out:
# (999, 17)

# %%
# 3.2 transforming runtime to numerical 
df["runtime"].value_counts()
# Out:
# runtime
# 100 min    23
# 130 min    23
# 129 min    22
# 101 min    22
# 113 min    22
#            ..
# 185 min     1
# 205 min     1
# 212 min     1
# 238 min     1
# 78 min      1
# Name: count, Length: 140, dtype: int64

# %%
def convert_runtime(runtime_series):
    """
    Converts a column with runtime values into numeric format.
    Strips 'min' if it exists and converts to integer.
    
    Args:
    runtime_series (pd.Series): Series containing runtime values.
    
    Returns:
    pd.Series: Numeric series with runtime values.
    """
    return (
        runtime_series.astype(str)  # Ensure all values are strings
        .str.lower()  # Convert to lowercase for uniformity
        .str.replace(r"\s*min$", "", regex=True)  # Remove 'min' at the end
        .str.strip()  # Remove any leading or trailing whitespace
        .replace(r"[^0-9]", "", regex=True)  # Remove any non-numeric characters
        .replace("", pd.NA)  # Convert empty strings to NaN
        .astype("Int64")  # Convert to float 
    )

df["runtime"] = convert_runtime(df["runtime"])
df["runtime"].value_counts()
# Out:
# runtime
# 100    23
# 130    23
# 129    22
# 101    22
# 113    22
#        ..
# 185     1
# 205     1
# 212     1
# 238     1
# 78      1
# Name: count, Length: 140, dtype: Int64

# %%
# 4. Transforming gross datatype
print(df['gross'].value_counts())
# Out:
# gross
# 4,360,000      5
# 25,000,000     2
# 5,450,000      2
# 5,321,508      2
# 9,600,000      2
#               ..
# 106,662        1
# 10,950         1
# 4,018,695      1
# 141,319,928    1
# 30,500,000     1
# Name: count, Length: 822, dtype: int64

# %%
# checking what years we are missing gross reveneue for 
df[df["gross"].isna()]["year"].value_counts().sort_index()
# Out:
# year
# 1920-01-01    1
# 1922-01-01    1
# 1928-01-01    1
# 1931-01-01    1
# 1932-01-01    2
#              ..
# 2016-01-01    5
# 2017-01-01    2
# 2018-01-01    5
# 2019-01-01    7
# 2020-01-01    6
# Name: count, Length: 77, dtype: int64

# %%
# drama has most missing values
df[df["gross"].isna()]["genre"].value_counts()
# Out:
# genre
# Drama                        10
# Action, Crime, Drama          8
# Comedy, Drama                 6
# Drama, Romance                6
# Biography, Drama, History     5
#                              ..
# Crime, Drama, Horror          1
# Comedy, Drama, War            1
# Drama, Film-Noir, Mystery     1
# Comedy, Crime, Thriller       1
# Crime, Mystery, Thriller      1
# Name: count, Length: 91, dtype: int64

# %%
# transform `gross` to numeric 
df['gross'] = df['gross'].str.replace(',', '', regex=True) # remove commas before converting to numeric 
df['gross'] = pd.to_numeric(df['gross'], errors='coerce')

# %%
missing_gross = df["gross"].isnull().sum()
print("Number of missing 'gross' values before imputation:", missing_gross)

missing_rows = df[df["gross"].isna()]
cols_to_show = ["title", "year", "gross"]
print("\nRows with missing gross:\n", missing_rows[cols_to_show])
# Out:
# Number of missing 'gross' values before imputation: 169
#
# Rows with missing gross:
#                        title       year  gross
# 18                 Hamilton 2020-01-01    NaN
# 20          Soorarai Pottru 2020-01-01    NaN
# 30                  Seppuku 1962-01-01    NaN
# 32    It's a Wonderful Life 1946-01-01    NaN
# 46           Hotaru no haka 1988-01-01    NaN
# ..                      ...        ...    ...
# 993                  Blowup 1966-01-01    NaN
# 995  Breakfast at Tiffany's 1961-01-01    NaN
# 996                   Giant 1956-01-01    NaN
# 998                Lifeboat 1944-01-01    NaN
# 999            The 39 Steps 1935-01-01    NaN
#
# [169 rows x 3 columns]

# %%
# imputing median by year for the missing gross reveneues 
df['gross'] = df.groupby(['year'])['gross'].transform(lambda x: x.fillna(x.mean()))

# %%
missing_after = df["gross"].isna().sum()
print("Number of missing values in 'gross' after imputation:", missing_after)

missing_rows_after = df[df["gross"].isna()]
print("\nRows with missing gross:\n", missing_rows_after[cols_to_show])
# Out:
# Number of missing values in 'gross' after imputation: 11
#
# Rows with missing gross:
#                                   title       year  gross
# 18                            Hamilton 2020-01-01    NaN
# 20                     Soorarai Pottru 2020-01-01    NaN
# 205                               Soul 2020-01-01    NaN
# 321       Das Cabinet des Dr. Caligari 1920-01-01    NaN
# 464                        Dil Bechara 2020-01-01    NaN
# 567                             Freaks 1932-01-01    NaN
# 568                          Nosferatu 1922-01-01    NaN
# 612         The Trial of the Chicago 7 2020-01-01    NaN
# 613                               Druk 2020-01-01    NaN
# 712                  Shadow of a Doubt 1943-01-01    NaN
# 718  Scarface: The Shame of the Nation 1932-01-01    NaN

# %%
# drop the remaining missing gross values 
df = df.dropna(subset=["gross"])

# %% [markdown]
# #### Sanity Check

# %%
print("\nData types:\n", df.dtypes)
# Out:
# Data types:
#  link                   object
# title                  object
# year           datetime64[ns]
# cert                   object
# runtime                 Int64
# genre                  object
# imdb_rating           float64
# overview               object
# meta_score            float64
# director               object
# star1                  object
# star2                  object
# star3                  object
# star4                  object
# no_of_votes             int64
# gross                 float64
# decade                float64
# dtype: object

# %%
df.isna().sum()
# Out:
# link           0
# title          0
# year           0
# cert           0
# runtime        0
# genre          0
# imdb_rating    0
# overview       0
# meta_score     0
# director       0
# star1          0
# star2          0
# star3          0
# star4          0
# no_of_votes    0
# gross          0
# decade         0
# dtype: int64

# %%
print('Released Year Range:', df['year'].min(), 'to', df['year'].max())
print('IMDB Rating Range:', df['imdb_rating'].min(), 'to', df['imdb_rating'].max())
print('Meta Score Range:', df['meta_score'].min(), 'to', df['meta_score'].max())
print('Gross Range:', df['gross'].min(), 'to', df['gross'].max())
# Out:
# Released Year Range: 1921-01-01 00:00:00 to 2019-01-01 00:00:00
# IMDB Rating Range: 7.6 to 9.3
# Meta Score Range: 28.0 to 100.0
# Gross Range: 1305.0 to 936662225.0

# %% [markdown]
# ### Checking value counts of each column

# %%
for col in df.columns:
    print(f"Column name: {col}")
    print(df[col].value_counts(dropna=False))
    print("-"*50)
    print("\n")
# Out:
# Column name: link
# link
# https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg                    1
# https://m.media-amazon.com/images/M/MV5BY2EyZDlhNjItODYzNi00Mzc3LWJjOWUtMTViODU5MTExZWMyL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg            1
# https://m.media-amazon.com/images/M/MV5BODllYjM1ODItYjBmOC00MzkwLWJmM2YtMjMyZDU3MGJhNjc4L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX67_CR0,0,67,98_AL_.jpg    1
# https://m.media-amazon.com/images/M/MV5BNDYwOThlMDAtYWUwMS00MjY5LTliMGUtZWFiYTA5MjYwZDAyXkEyXkFqcGdeQXVyNjY1NTQ0NDg@._V1_UX67_CR0,0,67,98_AL_.jpg                    1
# https://m.media-amazon.com/images/M/MV5BMjA3Y2I4NjAtMDQyZS00ZGJhLWEwMzgtODBiNzE5Zjc1Nzk1L2ltYWdlXkEyXkFqcGdeQXVyNTc2MDU0NDE@._V1_UX67_CR0,0,67,98_AL_.jpg            1
#                                                                                                                                                                     ..
# https://m.media-amazon.com/images/M/MV5BMTg5MTE2NjA4OV5BMl5BanBnXkFtZTgwMTUyMjczMTE@._V1_UX67_CR0,0,67,98_AL_.jpg                                                    1
# https://m.media-amazon.com/images/M/MV5BOTgwMzFiMWYtZDhlNS00ODNkLWJiODAtZDVhNzgyNzJhYjQ4L2ltYWdlXkEyXkFqcGdeQXVyNzEzOTYxNTQ@._V1_UX67_CR0,0,67,98_AL_.jpg            1
# https://m.media-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_UX67_CR0,0,67,98_AL_.jpg                                                    1
# https://m.media-amazon.com/images/M/MV5BNzA1Njg4NzYxOV5BMl5BanBnXkFtZTgwODk5NjU3MzI@._V1_UX67_CR0,0,67,98_AL_.jpg                                                    1
# https://m.media-amazon.com/images/M/MV5BMTY5ODAzMTcwOF5BMl5BanBnXkFtZTcwMzYxNDYyNA@@._V1_UX67_CR0,0,67,98_AL_.jpg                                                    1
# Name: count, Length: 988, dtype: int64
# --------------------------------------------------
#
#
# Column name: title
# title
# Drishyam                    2
# The Shawshank Redemption    1
# Majo no takkyûbin           1
# The Sandlot                 1
# The Remains of the Day      1
#                            ..
# Guardians of the Galaxy     1
# Blade Runner 2049           1
# Her                         1
# Bohemian Rhapsody           1
# The 39 Steps                1
# Name: count, Length: 987, dtype: int64
# --------------------------------------------------
#
#
# Column name: year
# year
# 2014-01-01    32
# 2004-01-01    31
# 2009-01-01    29
# 2013-01-01    28
# 2016-01-01    28
#               ..
# 1926-01-01     1
# 1936-01-01     1
# 1924-01-01     1
# 1930-01-01     1
# 1921-01-01     1
# Name: count, Length: 94, dtype: int64
# --------------------------------------------------
#
#
# Column name: cert
# cert
# U           231
# A           197
# UA          174
# R           145
# Unrated      98
# PG-13        42
# PG           35
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# U/A           1
# Name: count, dtype: int64
# --------------------------------------------------
#
#
# Column name: runtime
# runtime
# 130    23
# 100    22
# 113    22
# 101    21
# 129    21
#        ..
# 185     1
# 205     1
# 212     1
# 238     1
# 78      1
# Name: count, Length: 139, dtype: Int64
# --------------------------------------------------
#
#
# Column name: genre
# genre
# Drama                         84
# Drama, Romance                37
# Comedy, Drama                 34
# Comedy, Drama, Romance        30
# Action, Crime, Drama          29
#                               ..
# Comedy, Music                  1
# Drama, Music, Mystery          1
# Action, Adventure, History     1
# Comedy, Musical, Romance       1
# Adventure, Comedy, War         1
# Name: count, Length: 199, dtype: int64
# --------------------------------------------------
#
#
# Column name: imdb_rating
# imdb_rating
# 7.70    157
# 7.80    147
# 8.00    141
# 8.10    125
# 7.60    122
# 7.90    103
# 8.20     67
# 8.30     44
# 8.40     31
# 8.50     20
# 8.60     13
# 8.70      5
# 8.80      5
# 8.90      3
# 9.00      3
# 9.20      1
# 9.30      1
# Name: count, dtype: int64
# --------------------------------------------------
#
#
# Column name: overview
# overview
# Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.                                                                                                           1
# A young man in a small Midwestern town struggles to care for his mentally-disabled younger brother and morbidly obese mother while attempting to pursue his own happiness.                                                       1
# In the summer of 1962, a new kid in town is taken under the wing of a young baseball prodigy and his rowdy team, resulting in many adventures.                                                                                   1
# A butler who sacrificed body and soul to service in the years leading up to World War II realizes too late how misguided his loyalty was to his lordly employer.                                                                 1
# Parallel tales of two sexually obsessed men, one hurting and annoying women physically and mentally, one wandering around the city talking to strangers and experiencing dimensions of life.                                     1
#                                                                                                                                                                                                                                 ..
# Only a short time after the first raid, Rama goes undercover with the thugs of Jakarta and plans to bring down the syndicate and uncover the corruption within his police force.                                                 1
# During World War II, the English mathematical genius Alan Turing tries to crack the German Enigma code with help from fellow mathematicians.                                                                                     1
# A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.                                                                                                              1
# Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years.                                                                          1
# A man in London tries to help a counter-espionage Agent. But when the Agent is killed, and the man stands accused, he must go on the run to save himself and stop a spy ring which is trying to steal top secret information.    1
# Name: count, Length: 988, dtype: int64
# --------------------------------------------------
#
#
# Column name: meta_score
# meta_score
# 77.97    153
# 76.00     32
# 84.00     29
# 90.00     28
# 85.00     27
#         ...
# 44.00      1
# 40.00      1
# 48.00      1
# 33.00      1
# 41.00      1
# Name: count, Length: 64, dtype: int64
# --------------------------------------------------
#
#
# Column name: director
# director
# Steven Spielberg    13
# Alfred Hitchcock    13
# Hayao Miyazaki      11
# Akira Kurosawa      10
# Martin Scorsese     10
#                     ..
# Tomas Alfredson      1
# Duncan Jones         1
# Jacques Audiard      1
# Gus Van Sant         1
# George Stevens       1
# Name: count, Length: 542, dtype: int64
# --------------------------------------------------
#
#
# Column name: star1
# star1
# Tom Hanks            11
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Leonardo DiCaprio     9
#                      ..
# Alan Mak              1
# Preity Zinta          1
# Javier Bardem         1
# Ki-duk Kim            1
# Robert Donat          1
# Name: count, Length: 652, dtype: int64
# --------------------------------------------------
#
#
# Column name: star2
# star2
# Emma Watson          7
# Matt Damon           5
# Ian McKellen         4
# Diane Keaton         4
# Kate Winslet         4
#                     ..
# Irandhir Santos      1
# Viola Davis          1
# Morena Baccarin      1
# Shahab Hosseini      1
# Madeleine Carroll    1
# Name: count, Length: 833, dtype: int64
# --------------------------------------------------
#
#
# Column name: star3
# star3
# Rupert Grint          5
# Rachel McAdams        4
# Joe Pesci             4
# Jennifer Connelly     4
# Samuel L. Jackson     4
#                      ..
# John Gallagher Jr.    1
# Arifin Putra          1
# Matthew Goode         1
# Bradley Cooper        1
# Lucie Mannheim        1
# Name: count, Length: 881, dtype: int64
# --------------------------------------------------
#
#
# Column name: star4
# star4
# Michael Caine            4
# Catherine Keener         3
# Mark Ruffalo             3
# Domhnall Gleeson         2
# Jack Carson              2
#                         ..
# Derek Jacobi             1
# Ed Skrein                1
# Merila Zare'i            1
# Dibyendu Bhattacharya    1
# Godfrey Tearle           1
# Name: count, Length: 929, dtype: int64
# --------------------------------------------------
#
#
# Column name: no_of_votes
# no_of_votes
# 65341      2
# 2343110    1
# 125276     1
# 126871     1
# 78963      1
#           ..
# 685201     1
# 1043455    1
# 461823     1
# 540772     1
# 51853      1
# Name: count, Length: 987, dtype: int64
# --------------------------------------------------
#
#
# Column name: gross
# gross
# 29324714.67     10
# 150421418.00     7
# 4360000.00       6
# 14548761.25      5
# 5450000.00       5
#                 ..
# 4018695.00       1
# 141319928.00     1
# 106954678.00     1
# 8060.00          1
# 3448760.00       1
# Name: count, Length: 883, dtype: int64
# --------------------------------------------------
#
#
# Column name: decade
# decade
# 2010.00    242
# 2000.00    237
# 1990.00    150
# 1980.00     89
# 1970.00     76
# 1960.00     73
# 1950.00     56
# 1940.00     34
# 1930.00     22
# 1920.00      9
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# ### Dropping values we don't need
# * link, description, etc ...
# * Durham title appears twice
# * gross is exactly 29324714.67 for 10 titles, is this strange?

# %%
df.drop(['link', 'overview'], axis=1, inplace=True)

# %%
# look up durham in title column 
drishyam_entries = df[df['title'].str.contains('Drishyam', case=False, na=False)]
print(drishyam_entries) # seems to be 2 different movies with the same title
# Out:
#         title       year cert  runtime                   genre  imdb_rating  \
# 87   Drishyam 2013-01-01    U      160  Crime, Drama, Thriller         8.30
# 136  Drishyam 2015-01-01   UA      163   Crime, Drama, Mystery         8.20
#
#      meta_score         director       star1         star2         star3  \
# 87        77.97    Jeethu Joseph    Mohanlal         Meena  Asha Sharath
# 136       77.97  Nishikant Kamat  Ajay Devgn  Shriya Saran          Tabu
#
#             star4  no_of_votes       gross  decade
# 87         Ansiba        30722 47605822.11 2010.00
# 136  Rajat Kapoor        70367   739478.00 2010.00

# %% [markdown]
# ## EDA after Data Cleaning

# %%
display(df.head())
display(df.info())
display(df.describe(include='all'))
# Out:
#                       title       year cert  runtime                 genre  \
# 0  The Shawshank Redemption 1994-01-01    A      142                 Drama
# 1             The Godfather 1972-01-01    A      175          Crime, Drama
# 2           The Dark Knight 2008-01-01   UA      152  Action, Crime, Drama
# 3    The Godfather: Part II 1974-01-01    A      202          Crime, Drama
# 4              12 Angry Men 1957-01-01    U       96          Crime, Drama
#
#    imdb_rating  meta_score              director           star1  \
# 0         9.30       80.00        Frank Darabont     Tim Robbins
# 1         9.20      100.00  Francis Ford Coppola   Marlon Brando
# 2         9.00       84.00     Christopher Nolan  Christian Bale
# 3         9.00       90.00  Francis Ford Coppola       Al Pacino
# 4         9.00       96.00          Sidney Lumet     Henry Fonda
#
#             star2          star3           star4  no_of_votes        gross  \
# 0  Morgan Freeman     Bob Gunton  William Sadler      2343110  28341469.00
# 1       Al Pacino     James Caan    Diane Keaton      1620367 134966411.00
# 2    Heath Ledger  Aaron Eckhart   Michael Caine      2303232 534858444.00
# 3  Robert De Niro  Robert Duvall    Diane Keaton      1129952  57300000.00
# 4     Lee J. Cobb  Martin Balsam    John Fiedler       689845   4360000.00
#
#    decade
# 0 1990.00
# 1 1970.00
# 2 2000.00
# 3 1970.00
# 4 1950.00
# <class 'pandas.core.frame.DataFrame'>
# Index: 988 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        988 non-null    object
#  1   year         988 non-null    datetime64[ns]
#  2   cert         988 non-null    object
#  3   runtime      988 non-null    Int64
#  4   genre        988 non-null    object
#  5   imdb_rating  988 non-null    float64
#  6   meta_score   988 non-null    float64
#  7   director     988 non-null    object
#  8   star1        988 non-null    object
#  9   star2        988 non-null    object
#  10  star3        988 non-null    object
#  11  star4        988 non-null    object
#  12  no_of_votes  988 non-null    int64
#  13  gross        988 non-null    float64
#  14  decade       988 non-null    float64
# dtypes: Int64(1), datetime64[ns](1), float64(4), int64(1), object(8)
# memory usage: 124.5+ KB
# None
#            title                           year cert  runtime  genre  \
# count        988                            988  988   988.00    988
# unique       987                            NaN   16     <NA>    199
# top     Drishyam                            NaN    U     <NA>  Drama
# freq           2                            NaN  231     <NA>     84
# mean         NaN  1991-05-10 03:26:57.813765120  NaN   123.03    NaN
# min          NaN            1921-01-01 00:00:00  NaN    45.00    NaN
# 25%          NaN            1976-01-01 00:00:00  NaN   103.00    NaN
# 50%          NaN            1999-01-01 00:00:00  NaN   119.00    NaN
# 75%          NaN            2009-01-01 00:00:00  NaN   137.00    NaN
# max          NaN            2019-01-01 00:00:00  NaN   321.00    NaN
# std          NaN                            NaN  NaN    28.06    NaN
#
#         imdb_rating  meta_score          director      star1        star2  \
# count        988.00      988.00               988        988          988
# unique          NaN         NaN               542        652          833
# top             NaN         NaN  Steven Spielberg  Tom Hanks  Emma Watson
# freq            NaN         NaN                13         11            7
# mean           7.95       77.93               NaN        NaN          NaN
# min            7.60       28.00               NaN        NaN          NaN
# 25%            7.70       72.00               NaN        NaN          NaN
# 50%            7.90       77.97               NaN        NaN          NaN
# 75%            8.10       85.25               NaN        NaN          NaN
# max            9.30      100.00               NaN        NaN          NaN
# std            0.28       11.41               NaN        NaN          NaN
#
#                star3          star4  no_of_votes        gross  decade
# count            988            988       988.00       988.00  988.00
# unique           881            929          NaN          NaN     NaN
# top     Rupert Grint  Michael Caine          NaN          NaN     NaN
# freq               5              4          NaN          NaN     NaN
# mean             NaN            NaN    275957.23  66089395.33 1986.68
# min              NaN            NaN     25088.00      1305.00 1920.00
# 25%              NaN            NaN     56287.50   4128093.25 1970.00
# 50%              NaN            NaN    139966.50  27904009.50 1990.00
# 75%              NaN            NaN    377110.75  83912756.72 2000.00
# max              NaN            NaN   2343110.00 936662225.00 2010.00
# std              NaN            NaN    328627.79 102520771.91   22.79

# %% [markdown]
# #### Distribution of Key Features

# %%
fig, axs = plt.subplots(3, 2, figsize=(14, 14))
axs = axs.ravel()

cols = ['imdb_rating', 'meta_score', 'gross', 'runtime', 'no_of_votes', 'year']
for i, col in enumerate(cols):
    sns.histplot(df[col].dropna(), kde=True, ax=axs[i], bins=30)
    axs[i].set_title(f'{col} Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation Analysis

# %%
plt.figure(figsize=(10, 8))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Heatmap (Numerical Values Only)')
plt.show()

# %% [markdown]
# ## Relationship Between `certificate` and `IMDB Rating`

# %% [markdown]
# **Distribution of IMDb Ratings by Certificate**

# %%
df.groupby('cert')['imdb_rating'].describe()
# Out:
#           count  mean  std  min  25%  50%  75%  max
# cert
# 16         1.00  8.10  NaN 8.10 8.10 8.10 8.10 8.10
# A        197.00  8.00 0.35 7.60 7.70 8.00 8.20 9.30
# Approved  11.00  7.95 0.17 7.70 7.80 8.00 8.10 8.10
# G         12.00  8.00 0.31 7.60 7.70 8.00 8.15 8.50
# GP         2.00  7.85 0.35 7.60 7.72 7.85 7.97 8.10
# PG        35.00  7.93 0.21 7.60 7.80 7.90 8.10 8.60
# PG-13     42.00  7.78 0.17 7.60 7.60 7.70 7.90 8.30
# Passed    34.00  8.02 0.21 7.60 7.90 8.05 8.20 8.40
# R        145.00  7.87 0.22 7.60 7.70 7.80 8.00 8.60
# TV-14      1.00  8.30  NaN 8.30 8.30 8.30 8.30 8.30
# TV-MA      1.00  8.10  NaN 8.10 8.10 8.10 8.10 8.10
# TV-PG      3.00  7.90 0.17 7.70 7.85 8.00 8.00 8.00
# U        231.00  7.98 0.28 7.60 7.75 8.00 8.10 9.00
# U/A        1.00  7.60  NaN 7.60 7.60 7.60 7.60 7.60
# UA       174.00  7.96 0.28 7.60 7.70 7.90 8.10 9.00
# Unrated   98.00  7.93 0.21 7.60 7.80 8.00 8.10 8.60

# %%
# what year is the unrated movies released? 
unrated_years = df[df['cert'] == 'Unrated']['year'].sort_values()
unrated_years
# Out:
# 462   1925-01-01
# 126   1927-01-01
# 717   1933-01-01
# 999   1935-01-01
# 716   1935-01-01
#          ...
# 747   2015-01-01
# 885   2015-01-01
# 574   2016-01-01
# 721   2017-01-01
# 54    2017-01-01
# Name: year, Length: 98, dtype: datetime64[ns]

# %% [markdown]
# **Since the modern MPAA rating system was implemented in 1968, any films in the unrated category that was released prior to that, we will consolidate in a `OldCode` category.**
#
# Prior to 1968 the Production Code Administration was the primary regulatory system (roughly 1934-1968), often resulting in seals like `Passed` or `Approved`.

# %% [markdown]
# ### Cert type Data Cleaning and Consolidation

# %%
cert_simplified_map = {
    'A'       : 'R',
    'Approved': 'OldCode',
    'G'       : 'G',
    'GP'      : 'PG',
    'PG'      : 'PG',
    'PG-13'   : 'PG-13',
    'Passed'  : 'OldCode',
    'R'       : 'R',
    'U'       : 'G',
    'U/A'     : 'PG',
    'UA'      : 'PG',
    'Unrated' : 'Unrated',
    '16'      : 'R',
    'TV-14'   : 'Dropped',
    'TV-MA'   : 'Dropped',
    'TV-PG'   : 'Dropped'
}

# Apply the initial mapping to create 'cert_simplified' in df
df['cert_simplified'] = df['cert'].map(cert_simplified_map)

# Apply the pre-1968 Unrated logic
condition_mask = (df['cert'] == 'Unrated') & (df['year'].dt.year < 1968)
print(f"Number of pre-1968 'Unrated' rows to re-categorize as 'OldCode': {condition_mask.sum()}")
print(f"Number of post-1968 'Unrated' rows: {df.loc[~condition_mask, 'cert'].value_counts().get('Unrated', 0)}")
df.loc[condition_mask, 'cert_simplified'] = 'OldCode'

# We keep ALL rows, including 'Dropped', for the summary table aggregation
df_for_agg = df.copy()

# Group by the original certificate AND the final simplified category, then count
df_counts = df_for_agg.groupby(['cert', 'cert_simplified']).size().reset_index(name='count')

description_map = {
    'A'       : "Indian rating (18+)",
    'Approved': "Historic Production rating used pre-1968",
    'G'       : "General audiences",
    'GP'      : "Early variant of today's PG",
    'PG'      : "Parental Guidance suggested",
    'PG-13'   : "Parents strongly cautioned (under 13)",
    'Passed'  : "Historic Production rating used pre-1968",
    'R'       : "Restricted audiences",
    'U'       : "Indian rating (all ages)",
    'U/A'     : "Indian rating, PG (under 12)",
    'UA'      : "Indian rating, PG (under 12)",
    'Unrated' : "No MPAA (international/independent/pre-1968)",
    '16'      : "European countries (16+)",
    'TV-14'   : "Television rating for viewers 14 and older",
    'TV-MA'   : "Television rating for mature audiences",
    'TV-PG'   : "Television rating for PG"
}

df_counts['description'] = df_counts['cert'].map(description_map)
df_counts['description'].fillna('N/A', inplace=True)

ordered_cats = ["G", "PG", "PG-13", "R", "Unrated", "OldCode", "Dropped"]
cat_type = CategoricalDtype(categories=ordered_cats, ordered=True)

df_counts['cert_simplified'] = df_counts['cert_simplified'].astype(cat_type)

df_sorted = df_counts.sort_values(
    by=['cert_simplified', 'cert']
).reset_index(drop=True)

df_renamed = df_sorted.rename(columns={
    'cert': 'Original Rating',
    'count': 'Frequency',
    'description': 'Description',
    'cert_simplified': 'Consolidated Rating'
})

table_data = df_renamed[[
    'Original Rating',
    'Frequency',
    'Description',
    'Consolidated Rating'
]]

styled_table = (
    table_data
    .style
    .hide(axis='index')
    .set_caption("Summary of Rating Consolidation") 
    .set_table_styles(
        [
            {
                "selector": "th",
                "props": [
                    ("background-color", "#DCE6F1"),
                    ("color", "black"),
                    ("text-align", "left"),
                    ("font-weight", "bold")
                ]
            },
            {
                "selector": "caption",
                "props": [
                    ("font-size", "120%"),
                    ("font-weight", "bold"),
                    ("text-align", "center"),
                    ("caption-side", "top"),
                    ("padding-bottom", "10px")
                ]
            },
            {
                 "selector": "td",
                 "props": [
                     ("padding", "4px 8px"),
                     ("text-align", "left")
                 ]
             }
        ]
    )
    .set_properties(**{'text-align': 'left', 'border': '1px solid #ddd'})
)
styled_table
# Out:
# Number of pre-1968 'Unrated' rows to re-categorize as 'OldCode': 52
# Number of post-1968 'Unrated' rows: 46
# <style type="text/css">
# #T_f45ec th {
#   background-color: #DCE6F1;
#   color: black;
#   text-align: left;
#   font-weight: bold;
# }
# #T_f45ec caption {
#   font-size: 120%;
#   font-weight: bold;
#   text-align: center;
#   caption-side: top;
#   padding-bottom: 10px;
# }
# #T_f45ec td {
#   padding: 4px 8px;
#   text-align: left;
# }
# #T_f45ec_row0_col0, #T_f45ec_row0_col1, #T_f45ec_row0_col2, #T_f45ec_row0_col3, #T_f45ec_row1_col0, #T_f45ec_row1_col1, #T_f45ec_row1_col2, #T_f45ec_row1_col3, #T_f45ec_row2_col0, #T_f45ec_row2_col1, #T_f45ec_row2_col2, #T_f45ec_row2_col3, #T_f45ec_row3_col0, #T_f45ec_row3_col1, #T_f45ec_row3_col2, #T_f45ec_row3_col3, #T_f45ec_row4_col0, #T_f45ec_row4_col1, #T_f45ec_row4_col2, #T_f45ec_row4_col3, #T_f45ec_row5_col0, #T_f45ec_row5_col1, #T_f45ec_row5_col2, #T_f45ec_row5_col3, #T_f45ec_row6_col0, #T_f45ec_row6_col1, #T_f45ec_row6_col2, #T_f45ec_row6_col3, #T_f45ec_row7_col0, #T_f45ec_row7_col1, #T_f45ec_row7_col2, #T_f45ec_row7_col3, #T_f45ec_row8_col0, #T_f45ec_row8_col1, #T_f45ec_row8_col2, #T_f45ec_row8_col3, #T_f45ec_row9_col0, #T_f45ec_row9_col1, #T_f45ec_row9_col2, #T_f45ec_row9_col3, #T_f45ec_row10_col0, #T_f45ec_row10_col1, #T_f45ec_row10_col2, #T_f45ec_row10_col3, #T_f45ec_row11_col0, #T_f45ec_row11_col1, #T_f45ec_row11_col2, #T_f45ec_row11_col3, #T_f45ec_row12_col0, #T_f45ec_row12_col1, #T_f45ec_row12_col2, #T_f45ec_row12_col3, #T_f45ec_row13_col0, #T_f45ec_row13_col1, #T_f45ec_row13_col2, #T_f45ec_row13_col3, #T_f45ec_row14_col0, #T_f45ec_row14_col1, #T_f45ec_row14_col2, #T_f45ec_row14_col3, #T_f45ec_row15_col0, #T_f45ec_row15_col1, #T_f45ec_row15_col2, #T_f45ec_row15_col3, #T_f45ec_row16_col0, #T_f45ec_row16_col1, #T_f45ec_row16_col2, #T_f45ec_row16_col3 {
#   text-align: left;
#   border: 1px solid #ddd;
# }
# </style>
# <table id="T_f45ec">
#   <caption>Summary of Rating Consolidation</caption>
#   <thead>
#     <tr>
#       <th id="T_f45ec_level0_col0" class="col_heading level0 col0" >Original Rating</th>
#       <th id="T_f45ec_level0_col1" class="col_heading level0 col1" >Frequency</th>
#       <th id="T_f45ec_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_f45ec_level0_col3" class="col_heading level0 col3" >Consolidated Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f45ec_row0_col0" class="data row0 col0" >G</td>
#       <td id="T_f45ec_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_f45ec_row0_col2" class="data row0 col2" >General audiences</td>
#       <td id="T_f45ec_row0_col3" class="data row0 col3" >G</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row1_col0" class="data row1 col0" >U</td>
#       <td id="T_f45ec_row1_col1" class="data row1 col1" >231</td>
#       <td id="T_f45ec_row1_col2" class="data row1 col2" >Indian rating (all ages)</td>
#       <td id="T_f45ec_row1_col3" class="data row1 col3" >G</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row2_col0" class="data row2 col0" >GP</td>
#       <td id="T_f45ec_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_f45ec_row2_col2" class="data row2 col2" >Early variant of today's PG</td>
#       <td id="T_f45ec_row2_col3" class="data row2 col3" >PG</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row3_col0" class="data row3 col0" >PG</td>
#       <td id="T_f45ec_row3_col1" class="data row3 col1" >35</td>
#       <td id="T_f45ec_row3_col2" class="data row3 col2" >Parental Guidance suggested</td>
#       <td id="T_f45ec_row3_col3" class="data row3 col3" >PG</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row4_col0" class="data row4 col0" >U/A</td>
#       <td id="T_f45ec_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_f45ec_row4_col2" class="data row4 col2" >Indian rating, PG (under 12)</td>
#       <td id="T_f45ec_row4_col3" class="data row4 col3" >PG</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row5_col0" class="data row5 col0" >UA</td>
#       <td id="T_f45ec_row5_col1" class="data row5 col1" >174</td>
#       <td id="T_f45ec_row5_col2" class="data row5 col2" >Indian rating, PG (under 12)</td>
#       <td id="T_f45ec_row5_col3" class="data row5 col3" >PG</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row6_col0" class="data row6 col0" >PG-13</td>
#       <td id="T_f45ec_row6_col1" class="data row6 col1" >42</td>
#       <td id="T_f45ec_row6_col2" class="data row6 col2" >Parents strongly cautioned (under 13)</td>
#       <td id="T_f45ec_row6_col3" class="data row6 col3" >PG-13</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_f45ec_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_f45ec_row7_col2" class="data row7 col2" >European countries (16+)</td>
#       <td id="T_f45ec_row7_col3" class="data row7 col3" >R</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row8_col0" class="data row8 col0" >A</td>
#       <td id="T_f45ec_row8_col1" class="data row8 col1" >197</td>
#       <td id="T_f45ec_row8_col2" class="data row8 col2" >Indian rating (18+)</td>
#       <td id="T_f45ec_row8_col3" class="data row8 col3" >R</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row9_col0" class="data row9 col0" >R</td>
#       <td id="T_f45ec_row9_col1" class="data row9 col1" >145</td>
#       <td id="T_f45ec_row9_col2" class="data row9 col2" >Restricted audiences</td>
#       <td id="T_f45ec_row9_col3" class="data row9 col3" >R</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row10_col0" class="data row10 col0" >Unrated</td>
#       <td id="T_f45ec_row10_col1" class="data row10 col1" >46</td>
#       <td id="T_f45ec_row10_col2" class="data row10 col2" >No MPAA (international/independent/pre-1968)</td>
#       <td id="T_f45ec_row10_col3" class="data row10 col3" >Unrated</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row11_col0" class="data row11 col0" >Approved</td>
#       <td id="T_f45ec_row11_col1" class="data row11 col1" >11</td>
#       <td id="T_f45ec_row11_col2" class="data row11 col2" >Historic Production rating used pre-1968</td>
#       <td id="T_f45ec_row11_col3" class="data row11 col3" >OldCode</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row12_col0" class="data row12 col0" >Passed</td>
#       <td id="T_f45ec_row12_col1" class="data row12 col1" >34</td>
#       <td id="T_f45ec_row12_col2" class="data row12 col2" >Historic Production rating used pre-1968</td>
#       <td id="T_f45ec_row12_col3" class="data row12 col3" >OldCode</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row13_col0" class="data row13 col0" >Unrated</td>
#       <td id="T_f45ec_row13_col1" class="data row13 col1" >52</td>
#       <td id="T_f45ec_row13_col2" class="data row13 col2" >No MPAA (international/independent/pre-1968)</td>
#       <td id="T_f45ec_row13_col3" class="data row13 col3" >OldCode</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row14_col0" class="data row14 col0" >TV-14</td>
#       <td id="T_f45ec_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_f45ec_row14_col2" class="data row14 col2" >Television rating for viewers 14 and older</td>
#       <td id="T_f45ec_row14_col3" class="data row14 col3" >Dropped</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row15_col0" class="data row15 col0" >TV-MA</td>
#       <td id="T_f45ec_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_f45ec_row15_col2" class="data row15 col2" >Television rating for mature audiences</td>
#       <td id="T_f45ec_row15_col3" class="data row15 col3" >Dropped</td>
#     </tr>
#     <tr>
#       <td id="T_f45ec_row16_col0" class="data row16 col0" >TV-PG</td>
#       <td id="T_f45ec_row16_col1" class="data row16 col1" >3</td>
#       <td id="T_f45ec_row16_col2" class="data row16 col2" >Television rating for PG</td>
#       <td id="T_f45ec_row16_col3" class="data row16 col3" >Dropped</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Sanity Check**

# %%
df.groupby('cert_simplified')['imdb_rating'].describe()
# Out:
#                  count  mean  std  min  25%  50%  75%  max
# cert_simplified
# Dropped           5.00  8.02 0.22 7.70 8.00 8.00 8.10 8.30
# G               243.00  7.98 0.28 7.60 7.70 8.00 8.10 9.00
# OldCode          97.00  8.00 0.20 7.60 7.80 8.00 8.10 8.60
# PG              212.00  7.95 0.27 7.60 7.70 7.90 8.10 9.00
# PG-13            42.00  7.78 0.17 7.60 7.60 7.70 7.90 8.30
# R               343.00  7.94 0.31 7.60 7.70 7.90 8.10 9.30
# Unrated          46.00  7.86 0.20 7.60 7.70 7.80 8.00 8.40

# %%
print(f"Shape of df BEFORE dropping rows: {df.shape}")
print("Value counts BEFORE dropping:")
print(df['cert_simplified'].value_counts())

df = df[df['cert_simplified'] != 'Dropped'].copy()

print(f"\nShape of df AFTER dropping rows: {df.shape}")
print("Value counts AFTER dropping:")
print(df['cert_simplified'].value_counts())
# Out:
# Shape of df BEFORE dropping rows: (988, 16)
# Value counts BEFORE dropping:
# cert_simplified
# R          343
# G          243
# PG         212
# OldCode     97
# Unrated     46
# PG-13       42
# Dropped      5
# Name: count, dtype: int64
#
# Shape of df AFTER dropping rows: (983, 16)
# Value counts AFTER dropping:
# cert_simplified
# R          343
# G          243
# PG         212
# OldCode     97
# Unrated     46
# PG-13       42
# Name: count, dtype: int64

# %%
df.groupby('cert_simplified')['imdb_rating'].describe()
# Out:
#                  count  mean  std  min  25%  50%  75%  max
# cert_simplified
# G               243.00  7.98 0.28 7.60 7.70 8.00 8.10 9.00
# OldCode          97.00  8.00 0.20 7.60 7.80 8.00 8.10 8.60
# PG              212.00  7.95 0.27 7.60 7.70 7.90 8.10 9.00
# PG-13            42.00  7.78 0.17 7.60 7.60 7.70 7.90 8.30
# R               343.00  7.94 0.31 7.60 7.70 7.90 8.10 9.30
# Unrated          46.00  7.86 0.20 7.60 7.70 7.80 8.00 8.40

# %%
post_1968_unrated = df[(df['cert'] == 'Unrated') & (df['year'].dt.year >= 1968)]
post_1968_unrated[['title', 'genre', 'director', 'imdb_rating', 'star1', 'year']].head()
# Out:
#                          title                      genre           director  \
# 54   Ayla: The Daughter of War  Biography, Drama, History          Can Ulkay
# 92              Babam ve Oglum              Drama, Family        Çagan Irmak
# 138                Mandariinid                 Drama, War     Zaza Urushadze
# 163                     Eskiya     Crime, Drama, Thriller       Yavuz Turgul
# 206                 Kis Uykusu                      Drama  Nuri Bilge Ceylan
#
#      imdb_rating           star1       year
# 54          8.40       Erdem Can 2017-01-01
# 92          8.30  Çetin Tekindor 2005-01-01
# 138         8.20   Lembit Ulfsak 2013-01-01
# 163         8.20       Sener Sen 1996-01-01
# 206         8.10  Haluk Bilginer 2014-01-01

# %%
fig = px.box(
    df, 
    x='cert_simplified', 
    y='imdb_rating',
    title='Distribution of IMDb Ratings by Certificate',
    labels={'cert': 'Certificate', 'imdb_rating': 'IMDb Rating'}, 
    color='cert_simplified', 
    color_discrete_sequence=px.colors.sequential.Viridis
)
fig.show("png")

# %% [markdown]
# **Boxplot of Ratings by Certificate**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='cert_simplified', y='imdb_rating', palette='viridis')
plt.title('IMDB Ratings by Certificate')
plt.xlabel('Certificate')
plt.ylabel('IMDB Rating')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %% [markdown]
# Line in the middle is median rating, points outside of whiskers are outliers.

# %% [markdown]
# **Violinplot of Ratings by Certificate**

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='cert_simplified', 
               y='imdb_rating', 
               inner='quartile',
               palette='viridis'
)
plt.title('IMDB Score by Certificate (Rating)')
plt.xlabel('Certificate')
plt.ylabel('IMDB Score')
plt.tight_layout()
plt.show()
plt.savefig('imdb_score_by_certificate.png')

# %% [markdown]
# **Average IMDb Score by Certificate**

# %%
df_grouped = df.groupby('cert_simplified')['imdb_rating'].mean().reset_index()
df_grouped.rename(columns={'imdb_rating': 'avg_rating'}, inplace=True)
df_grouped.sort_values('avg_rating', ascending=False, inplace=True)
sns.set_theme(style="whitegrid")  

plt.figure(figsize=(8, 6))
ax = sns.barplot(
    data=df_grouped, 
    x='avg_rating', 
    y='cert_simplified', 
    palette='viridis' 
)
for i, v in enumerate(df_grouped['avg_rating']):
    ax.text(v + 0.01, i, f"{v:.2f}", va='center', fontsize=10)

plt.title('Average IMDB Score by Movie Certificate (Rating)', fontsize=14, pad=15)
plt.xlabel('Average IMDB Score', fontsize=12)
plt.ylabel('Certificate', fontsize=12)
plt.show()

# %%
df_count = df.groupby('cert_simplified')['imdb_rating'].count().reset_index(name='count')
df_grouped = df.groupby('cert_simplified')['imdb_rating'].mean().reset_index()
df_grouped.rename(columns={'imdb_rating': 'avg_rating'}, inplace=True)
df_grouped.sort_values('avg_rating', ascending=False, inplace=True)
df_grouped['label'] = df_grouped.apply(lambda x: f"{x['cert_simplified']} ({x['avg_rating']:.2f})", axis=1)


fig = px.bar(
    df_grouped, 
    x='avg_rating', 
    y='cert_simplified', 
    orientation='h',
    color='cert_simplified',  
    text='avg_rating',        
    color_discrete_sequence=px.colors.sequential.Viridis,  
    title='Average IMDB Rating by Movie Certificate'
)

fig.update_traces(
    texttemplate='%{text:.2f}',  
    textposition='inside',
    insidetextanchor='middle',
    textfont_color='white',
    hovertemplate='Certificate: %{y}<br>Avg Rating: %{x:.2f}' 
)

fig.update_layout(
    xaxis_title='Average IMDB Score',
    yaxis_title='Certificate',
    template='plotly_white',      
    showlegend=False,             
    width=800, 
    height=500,
    font=dict(size=13), 
    margin=dict(l=50, r=50, t=80, b=40)
)

fig.show()

# %% [markdown]
# #### Count the Number of Movies by Certificate and Year

# %%
grouped = df.groupby(['decade', 'cert_simplified']).size().reset_index(name='movie_count')
pivoted = grouped.pivot(index='decade', columns='cert_simplified', values='movie_count').fillna(0)
pivoted.sort_index(inplace=True)

certificates = pivoted.columns.tolist()
n_certificates = len(certificates)
n_rows = 4
n_cols = (n_certificates // n_rows) + (1 if n_certificates % n_rows != 0 else 0)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15))
axes = axes.flatten()

for i, cert in enumerate(certificates):
    pivoted[cert].plot(kind='bar', ax=axes[i], color='steelblue')
    axes[i].set_title(cert, fontsize=14)
    axes[i].tick_params(axis='x', labelrotation=0)
    axes[i].set_ylabel('Certificate Count')
    axes[i].tick_params(axis='x', labelrotation=0)

for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Movie Count by Decade by Certificate', fontsize=20, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relationship between Gross and Certificate

# %%
df.groupby('cert_simplified')['gross'].describe()
# Out:
#                  count         mean          std       min         25%  \
# cert_simplified
# G               243.00  80354333.95 111700680.31  19181.00  5224816.00
# OldCode          97.00  13353136.32  22014849.30  10177.00   355613.00
# PG              212.00 111827390.24 151315304.87   7461.00 10612078.00
# PG-13            42.00  38596861.23  53087990.80 355613.00  4422340.25
# R               343.00  49746668.57  62232076.91   1305.00  5352671.00
# Unrated          46.00  39253143.09  46407053.91   3296.00   172076.00
#
#                         50%          75%          max
# cert_simplified
# G               42318285.83 109822346.50 936662225.00
# OldCode          4905000.00  13551333.33  96645428.67
# PG              48711824.00 166421635.00 858373000.00
# PG-13           14330954.00  50360477.25 209028679.00
# R               26830000.00  70385452.50 363070709.00
# Unrated          2829895.00  79997391.61 121076954.14

# %% [markdown]
# **Boxplot of Gross by Certificate**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='cert_simplified', y='gross', palette='viridis')
plt.title('Gross Revenue by Certificate (Rating)')
plt.xlabel('Certificate')
plt.ylabel('Gross Revenue')
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions))

plt.ylabel('Gross Revenue $USD Millions')
plt.tight_layout()
plt.savefig('./images/revenue_by_certificate_boxplot.png')
plt.show()

# %%
# as plotly so I can see the values 
fig = px.box(
    df, 
    x='cert_simplified', 
    y='gross', 
    color='cert_simplified', 
    title='Gross Revenue by Certificate (Rating)',
    labels={'gross': 'Gross Revenue $USD Millions'},
    color_discrete_sequence=px.colors.sequential.Viridis
)

fig.update_layout(
    yaxis_tickprefix="$",
    yaxis_tickformat=","
)
fig.show()

# %% [markdown]
# **Violinplot of Gross by Certificate**

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='cert_simplified', 
               y='gross', 
               inner='quartile',
               palette='viridis'
)

plt.title('Gross Revenue by Certificate (Rating)')
plt.xlabel('Certificate')
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions))
plt.ylabel('Gross Revenue')
plt.tight_layout()
plt.savefig('./images/revenue_by_certificate_violinplot.png')
plt.show()

# %% [markdown]
# ### Average Gross revenue by Decade and Certificate

# %%
grouped_cert_decade = df.groupby(['decade', 'cert_simplified'])['gross'].mean().reset_index(name='avg_gross')

plt.figure(figsize=(10, 6))
sns.barplot(
    data=grouped_cert_decade,
    x='decade',          
    y='avg_gross',
    hue='cert_simplified',
    palette='Dark2'    
)
plt.title('Average Gross Revenue by Decade and Certificate', fontsize=14)
plt.xlabel('Decade', fontsize=12)
plt.ylabel('Average Gross (USD)', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions))
plt.legend(title='Certificate', fontsize=10, title_fontsize=10, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Average Gross revenue by Decade and Certificate Adjusted for Inflation

# %%
inflation_factors = { 1920: 14.7, 1930: 15.2, 1940: 18.6, 1950: 10.8, 1960: 8.8, 1970: 6.7, 1980: 3.3, 1990: 2.0, 2000: 1.5, 2010: 1.2, 2020: 1.0 }

def get_inflation_factor(decade):
    return inflation_factors.get(decade, 1.0)

df['gross_adj'] = df.apply(lambda row: row['gross'] * get_inflation_factor(row['decade']), axis=1)

# %%
grouped_cert_decade = df.groupby(['decade', 'cert_simplified'])['gross_adj'].mean().reset_index(name='avg_gross_adj')
plt.figure(figsize=(10, 6))

sns.barplot(
    data=grouped_cert_decade,
    x='decade',
    y='avg_gross_adj',
    hue='cert_simplified',
    palette='Dark2'
)

plt.title('Average Inflation-Adjusted Gross (2020 Dollars) by Decade and Certificate', fontsize=14)
plt.xlabel('Decade', fontsize=12)
plt.ylabel('Average Gross (Millions USD)', fontsize=12)
plt.legend(title='Certificate', fontsize=10, title_fontsize=10, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Split Up Genre into Separate Entries

# %%
df['genre'] = df['genre'].str.split(',')
df = df.explode('genre')

# %%
df['genre'] = (df['genre']
               .str.strip()               
               .str.strip(',')           
               .str.title()             
              )

genre_stats = df.groupby('genre').agg(
    Count=('gross', 'count'),
    Total_Gross=('gross', 'sum')
).reset_index()

genre_stats['Average_Gross'] = genre_stats['Total_Gross'] / genre_stats['Count']
genre_stats = genre_stats.sort_values(by='Average_Gross', ascending=False)

# %%
df.head()
# Out:
#                       title       year cert  runtime   genre  imdb_rating  \
# 0  The Shawshank Redemption 1994-01-01    A      142   Drama         9.30
# 1             The Godfather 1972-01-01    A      175   Crime         9.20
# 1             The Godfather 1972-01-01    A      175   Drama         9.20
# 2           The Dark Knight 2008-01-01   UA      152  Action         9.00
# 2           The Dark Knight 2008-01-01   UA      152   Crime         9.00
#
#    meta_score              director           star1           star2  \
# 0       80.00        Frank Darabont     Tim Robbins  Morgan Freeman
# 1      100.00  Francis Ford Coppola   Marlon Brando       Al Pacino
# 1      100.00  Francis Ford Coppola   Marlon Brando       Al Pacino
# 2       84.00     Christopher Nolan  Christian Bale    Heath Ledger
# 2       84.00     Christopher Nolan  Christian Bale    Heath Ledger
#
#            star3           star4  no_of_votes        gross  decade  \
# 0     Bob Gunton  William Sadler      2343110  28341469.00 1990.00
# 1     James Caan    Diane Keaton      1620367 134966411.00 1970.00
# 1     James Caan    Diane Keaton      1620367 134966411.00 1970.00
# 2  Aaron Eckhart   Michael Caine      2303232 534858444.00 2000.00
# 2  Aaron Eckhart   Michael Caine      2303232 534858444.00 2000.00
#
#   cert_simplified    gross_adj
# 0               R  56682938.00
# 1               R 904274953.70
# 1               R 904274953.70
# 2              PG 802287666.00
# 2              PG 802287666.00

# %% [markdown]
# ### Gross revenue by Decade and IMDb Score

# %%
rating_bins = [7.5, 8, 8.5, 9, 9.5]
rating_labels = ['7.5 - 8', '8 - 8.5', '8.5 - 9', '9 - 9.5']
df['rating_bin'] = pd.cut(df['imdb_rating'], bins=rating_bins, labels=rating_labels, include_lowest=True)
grouped = df.groupby(['decade', 'rating_bin'])['gross'].mean().reset_index(name='avg_gross')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    data=grouped,
    x='decade',          
    y='avg_gross',
    hue='rating_bin',    
    palette='Dark2'    
)
plt.title('Average Gross Revenue by Decade and IMDB Score', fontsize=14)
plt.xlabel('Decade', fontsize=12)
plt.ylabel('Average Gross (USD)', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions))
plt.legend(title='IMDB Score', fontsize=10, title_fontsize=10, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gross revenue by Decade and IMDb Score adjusted for inflation

# %%
df_grouped = df.groupby(['decade', 'rating_bin'])['gross_adj'].mean().reset_index(name='avg_gross_adj')
plt.figure(figsize=(10, 6))

sns.barplot(
    data=df_grouped,
    x='decade',
    y='avg_gross_adj',
    hue='rating_bin',
    palette='Dark2'
)

plt.title('Average Inflation-Adjusted Gross (2020 Dollars) by Decade and IMDB Rating', fontsize=14)
plt.xlabel('Decade', fontsize=12)
plt.ylabel('Average Gross (Millions USD)', fontsize=12)
plt.legend(title='IMDB Score', fontsize=10, title_fontsize=10, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Director Analysis: Summaries of IMDB Rating and Gross

# %%
# filters the DataFrame to include only directors with at least 2 films,
# then aggregates their average IMDb rating, average gross, and film count.
director_count = df['director'].value_counts().reset_index()
director_count.columns = ['director', 'num_films']

common_directors = director_count[director_count['num_films'] >= 2]['director']
df_filtered = df[df['director'].isin(common_directors)]

df_directors_agg = df_filtered.groupby('director', as_index=False).agg(
    avg_imdb_rating=('imdb_rating', 'mean'),
    avg_gross=('gross', 'mean'),
    num_films=('title', 'count')
)

df_directors_agg = df_directors_agg.sort_values('avg_imdb_rating', ascending=False)
df_top20_rating = df_directors_agg.head(20)
print(df_top20_rating)
# Out:
#                              director  avg_imdb_rating    avg_gross  num_films
# 135                    Frank Darabont             8.78 109686397.75          4
# 183                    Irvin Kershner             8.70 290475067.00          3
# 266                    Lana Wachowski             8.70 171479930.00          2
# 130                Fernando Meirelles             8.60   7563397.00          2
# 296                  Masaki Kobayashi             8.60  29324714.67          3
# 396                   Roberto Benigni             8.60  57598247.00          3
# 151                      George Lucas             8.60 322740140.00          3
# 341                   Olivier Nakache             8.50  13182281.00          3
# 397                      Roger Allers             8.50 422783777.00          3
# 357                     Peter Jackson             8.49 325428223.54         13
# 80                  Christopher Nolan             8.48 244372662.86         21
# 319                      Milos Forman             8.40  66979771.75          4
# 0                          Aamir Khan             8.40   1223869.00          2
# 282                    Makoto Shinkai             8.40   5017246.00          3
# 148                           Gayatri             8.40 103065642.60          3
# 53                    Bob Persichetti             8.40 190241310.00          3
# 131  Florian Henckel von Donnersmarck             8.40  11286112.00          3
# 180              Hrishikesh Mukherjee             8.40  24581160.71          2
# 66                          Can Ulkay             8.40 103065642.60          3
# 240                    Jonathan Demme             8.38 117388297.00          4

# %%
fig = px.bar(
    df_top20_rating, 
    x='director', 
    y='avg_imdb_rating',
    title='Top 20 Directors by Average IMDb Rating',
    labels={'director': 'Director', 'avg_imdb_rating': 'Average IMDb Rating'},
)
fig.update_layout(xaxis_tickangle=45)
fig.show()

# %% [markdown]
# #### Highest Gross Director

# %%
director_stats = (
    df.groupby('director')
      .agg(
          avg_rating=('imdb_rating', 'mean'),
          avg_gross=('gross', 'mean'), 
          count_movies=('gross','count')
      )
      .reset_index().sort_values(by='avg_gross', ascending=False)
)

director_stats.head(20)
# Out:
#              director  avg_rating    avg_gross  count_movies
# 35      Anthony Russo        8.08 551259850.75            12
# 147    Gareth Edwards        7.80 532177324.00             3
# 194       J.J. Abrams        7.83 474390301.67             9
# 260       Josh Cooley        7.80 434038008.00             3
# 424      Roger Allers        8.50 422783777.00             3
# 490        Tim Miller        8.00 363070709.00             3
# 201     James Cameron        8.08 361845089.75            12
# 204        James Gunn        7.80 361494850.50             6
# 65       Byron Howard        8.00 341268248.00             3
# 106       David Yates        7.80 326317907.00             9
# 380     Peter Jackson        8.49 325428223.54            13
# 101      David Leitch        7.70 324591735.00             3
# 261       Joss Whedon        7.90 324397032.00             6
# 157      George Lucas        8.60 322740140.00             3
# 492     Todd Phillips        8.30 320919109.00             4
# 250       Jon Favreau        7.90 318412101.00             3
# 377       Pete Docter        8.13 313127377.00             9
# 287       Lee Unkrich        8.30 312365447.50             6
# 406  Richard Marquand        8.30 309125409.00             3
# 167    Gore Verbinski        8.00 305413918.00             3

# %% [markdown]
# #### Highest IMDb Rated Director

# %%
director_stats = (
    df.groupby('director')
      .agg(
          avg_rating=('imdb_rating', 'mean'),
          avg_gross=('gross', 'mean'), 
          count_movies=('gross','count')
      )
      .reset_index().sort_values(by='avg_rating', ascending=False)
)

director_stats.head(20)
# Out:
#                              director  avg_rating    avg_gross  count_movies
# 140                    Frank Darabont        8.78 109686397.75             4
# 190                    Irvin Kershner        8.70 290475067.00             3
# 283                    Lana Wachowski        8.70 171479930.00             2
# 423                   Roberto Benigni        8.60  57598247.00             3
# 134                Fernando Meirelles        8.60   7563397.00             2
# 315                  Masaki Kobayashi        8.60  29324714.67             3
# 157                      George Lucas        8.60 322740140.00             3
# 363                   Olivier Nakache        8.50  13182281.00             3
# 424                      Roger Allers        8.50 422783777.00             3
# 380                     Peter Jackson        8.49 325428223.54            13
# 82                  Christopher Nolan        8.48 244372662.86            21
# 54                    Bob Persichetti        8.40 190241310.00             3
# 340                      Milos Forman        8.40  66979771.75             4
# 67                          Can Ulkay        8.40 103065642.60             3
# 135  Florian Henckel von Donnersmarck        8.40  11286112.00             3
# 299                    Makoto Shinkai        8.40   5017246.00             3
# 153                           Gayatri        8.40 103065642.60             3
# 343                     Nadine Labaki        8.40   1661096.00             1
# 0                          Aamir Khan        8.40   1223869.00             2
# 187              Hrishikesh Mukherjee        8.40  24581160.71             2

# %% [markdown]
# #### Director with most released movies

# %%
director_stats = (
    df.groupby('director')
      .agg(
          avg_rating=('imdb_rating', 'mean'),
          avg_gross=('gross', 'mean'), 
          count_movies=('gross','count')
      )
      .reset_index().sort_values(by='count_movies', ascending=False)
)

director_stats.head(20)
# Out:
#               director  avg_rating    avg_gross  count_movies
# 21    Alfred Hitchcock        8.03  10433901.34            35
# 178     Hayao Miyazaki        8.02  26476791.06            33
# 466   Steven Spielberg        8.03 185431996.58            31
# 312    Martin Scorsese        8.16  52453473.56            27
# 8       Akira Kurosawa        8.22  17951710.12            26
# 48        Billy Wilder        8.15  13580665.96            24
# 82   Christopher Nolan        8.48 244372662.86            21
# 459    Stanley Kubrick        8.20  46091457.56            21
# 99       David Fincher        7.98  93758120.90            21
# 388  Quentin Tarantino        8.16  84184096.38            21
# 524        Woody Allen        7.78  37378689.61            21
# 186       Howard Hawks        7.87   5634607.22            18
# 230          Joel Coen        7.82  16834619.17            18
# 73     Charles Chaplin        8.35   2009203.35            17
# 410         Rob Reiner        7.82  52146312.59            17
# 83      Clint Eastwood        7.89  67360062.41            17
# 516       Wes Anderson        7.85  36996263.47            17
# 408       Ridley Scott        8.06 130660839.35            17
# 240        John Huston        7.89  20796952.09            14
# 109   Denis Villeneuve        7.99  58678630.57            14

# %%
notable_directors = [
    "Steven Spielberg", 
    "Christopher Nolan", 
    "Peter Jackson",
    "Hayao Miyazaki", 
    "Martin Scorsese", 
    "Greta Gerwig", 
    "Anthony Russo",
    "George Lucas", 
    "Roger Allers", 
    "Gareth Edwards", 
    "Bong Joon Ho",
    "Quentin Tarantino", 
    "Luca Guadagnino", 
    "Wes Anderson",
    "Baz Luhrmann",
    "Oliver Stone",
    "James Cameron",
    "Denis Villeneuve",
    "David Fincher",
    "Damien Chazelle"
]

df_directors_agg['plot_category'] = df_directors_agg['director'].apply(
    lambda d: d if d in notable_directors else 'Others'
)

label_map = {
    "Steven Spielberg": "Steven Spielberg: Jurassic Park",
    "Christopher Nolan": "Christopher Nolan: Inception",
    "Peter Jackson": "Peter Jackson: Lord of the Rings",
    "Hayao Miyazaki": "Hayao Miyazaki: Spirited Away",
    "Martin Scorsese": "Martin Scorsese: Wolf of Wall Street",
    "Greta Gerwig": "Greta Gerwig: Barbie",
    "Anthony Russo": "Anthony Russo: Avengers",
    "George Lucas": "George Lucas: Star Wars",
    "Roger Allers": "Roger Allers: Lion King", 
    "Gareth Edwards": "Gareth Edwards: Godzilla",
    "Bong Joon Ho": "Bong Joon Ho: Parasite",
    "Quentin Tarantino": "Quentin Tarantino: Pulp Fiction",
    "Luca Guadagnino": "Luca Guadagnino: Call Me by Your Name", 
    "Wes Anderson": "Wes Anderson: Moonrise Kingdom", 
    "Baz Luhrmann": "Baz Luhrmann: The Great Gatsby",
    "Oliver Stone": "Oliver Stone: Snowden",
    "James Cameron": "James Cameron: Avatar",
    "Denis Villeneuve": "Denis Villeneuve: Dune",
    "David Fincher": "David Fincher: Fight Club",
    "Damien Chazelle": "Damien Chazelle: La La Land"
}

df_directors_agg['legend_label'] = df_directors_agg['director'].apply(
    lambda d: label_map[d] if d in label_map else 'Others'
)

color_map = {
    "Bong Joon Ho: Parasite": "deeppink",
    "Christopher Nolan: Inception": "darkblue",
    "Damien Chazelle: La La Land": "chartreuse",
    "David Fincher: Fight Club": "darkred",
    "Denis Villeneuve: Dune": "darkviolet",
    "Gareth Edwards: Godzilla": "turquoise",
    "George Lucas: Star Wars": "saddlebrown",
    "Greta Gerwig: Barbie": "hotpink",
    "Hayao Miyazaki: Spirited Away": "indigo",
    "James Cameron: Avatar": "blue",
    "Luca Guadagnino: Call Me by Your Name": "green",
    "Martin Scorsese: Wolf of Wall Street": "gold",
    "Oliver Stone: Snowden": "teal",
    "Peter Jackson: Lord of the Rings": "forestgreen",
    "Quentin Tarantino: Pulp Fiction": "darkorange",
    "Roger Allers: Lion King": "orchid",
    "Anthony Russo: Avengers": "lightseagreen",
    "Steven Spielberg: Jurassic Park": "crimson",
    "Wes Anderson: Moonrise Kingdom": "limegreen",
    "Others": "lightgray"
}

fig = px.scatter(
    df_directors_agg,
    x='avg_imdb_rating',
    y='avg_gross',
    hover_name='director',
    color='legend_label',           
    size='num_films',
    labels={
        'avg_imdb_rating': 'Average IMDb Rating',
        'avg_gross': 'Average Gross $USD (Millions)'
    },
    title='Average IMDb Rating vs Average Gross by Director (1920-2019)',
    color_discrete_map=color_map    
)

fig.update_layout(
    legend_title_text='Notable Directors',
    width=800,
    height=600
)

fig.show("png")

# %%
df['director'].nunique()
# Out:
# 540

# %%
director_stats_filtered = director_stats[director_stats['count_movies'] >= 2]

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=director_stats_filtered,
    x='avg_rating',
    y='avg_gross',
    size='count_movies',  
    alpha=0.7,             
    palette='Dark2'
)
sns.regplot(
    data=director_stats_filtered,
    x='avg_rating',
    y='avg_gross',
    scatter=False,
    ci=None,
    color='red'
)

highlighted_directors = [
    "Frank Darabont",
    "George Lucas",
    "Peter Jackson",
    "James Cameron",
    "Anthony Russo"
]

for i, row in director_stats_filtered.iterrows():
    if row['director'] in highlighted_directors:
        plt.text(
            x=row['avg_rating']+0.01,
            y=row['avg_gross']+0.01,
            s=row['director'],
            fontsize=9
        )


plt.title('Average IMDB Score vs. Average Gross by Director')
plt.xlabel('Average IMDB Score')
plt.ylabel('Average Gross')
plt.legend(title='Count of Movies', loc='upper left', bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()

# %%
top_rating = director_stats_filtered[['director', 'avg_rating', 'count_movies']].nlargest(10, 'avg_rating')
top_gross = director_stats_filtered[['director', 'avg_gross', 'count_movies']].nlargest(10, 'avg_gross')

# %% [markdown]
# ### Top 10 directors for average rating and gross revenue

# %%
shared_directors = ["Roger Allers"]
shared_palette = {
    "Roger Allers": "blue",
}
default_color = "steelblue"

# Helper function to pick color
def get_color_for_director(d):
    return shared_palette[d] if d in shared_palette else default_color

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))

# ================== FIRST SUBPLOT: Top 10 Directors by Rating ================== #
colors_top_rating = [get_color_for_director(d) for d in top_rating['director']]
sns.barplot(
    data=top_rating,
    x='avg_rating',
    y='director',
    palette=colors_top_rating,
    ax=ax1
)

for i, (rating_val, num_movies, director_name) in enumerate(zip(
        top_rating['avg_rating'], 
        top_rating['count_movies'],
        top_rating['director'])):
    color_label = colors_top_rating[i] 
    ax1.text(
        rating_val + 0.01,
        i,
        f"{rating_val:.2f} ({num_movies} movies)",
        va='center',
        fontsize=10,
        color='black'  
    )

ax1.set_title('Top 10 Directors by Average IMDB Rating', fontdict={'fontsize': 16})
ax1.set_xlabel('Average IMDB Rating')
ax1.set_ylabel('Director')

min_rating = top_rating['avg_rating'].min()
max_rating = top_rating['avg_rating'].max()
ax1.set_xlim(min_rating - 0.1, max_rating + 0.1)

# ================== SECOND SUBPLOT: Top 10 Directors by Gross ================== #
colors_top_gross = [get_color_for_director(d) for d in top_gross['director']]
sns.barplot(
    data=top_gross,
    x='avg_gross',
    y='director',
    palette=colors_top_gross,
    ax=ax2
)

min_gross = top_gross['avg_gross'].min()
max_gross = top_gross['avg_gross'].max()
ax2.set_xlim(min_gross - (max_gross * 0.05), max_gross * 1.1)

for i, (gross_val, num_movies, director_name) in enumerate(zip(
        top_gross['avg_gross'], 
        top_gross['count_movies'],
        top_gross['director'])):
    
    x_offset = 0.01 * max_gross 
    
    text_x = gross_val + x_offset
    
    gross_millions = gross_val / 1e6
    
    ax2.text(
        text_x,
        i,
        f"${gross_millions:,.0f}M ({num_movies} movies)",
        va='center',
        fontsize=10,
        color='black' 
    )

ax2.set_title('Top 10 Directors by Average Gross', fontdict={'fontsize': 16})
ax2.set_xlabel('Average Gross (USD)')
ax2.set_ylabel('')

ax2.xaxis.set_major_formatter(FuncFormatter(millions))
sns.despine(ax=ax1, top=True, right=True)
sns.despine(ax=ax2, top=True, right=True)
plt.tight_layout()
plt.show()

# %%
# save dataset 
df.to_csv('./data/imdb_cleaned.csv', index=False)
